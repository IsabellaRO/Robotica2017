# %% [markdown]
# # Entregável 1 - visão computacional

# %%
# %matplotlib inline
import cv2
from matplotlib import pyplot as plt
import numpy as np
import time as t
print "OpenCV Version : %s " % cv2.__version__
# Out:
# OpenCV Version : 2.4.8

# %% [markdown]
# # Equalização de histograma

# %%
rintin = cv2.imread("RinTinTin.jpg")

# %%
rintin.shape
# Out:
# (240, 320, 3)

# %%
rintin_gray = cv2.cvtColor(rintin, cv2.COLOR_RGB2GRAY)

# %%
rintin_gray.shape
# Out:
# (240, 320)

# %%
plt.imshow(rintin_gray, cmap="Greys_r", vmin=0, vmax=255)

# %%
hist,bins = np.histogram(rintin_gray.flatten(),256,[0,256])

cdf = hist.cumsum()
cdf_normalized = cdf * hist.max()/ cdf.max()

plt.plot(cdf_normalized, color = 'b')
plt.hist(rintin_gray.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %% [markdown]
# ## Atividade 1
#
# Realize as seguintes atividades:
#
# 1. O histograma fornecido aproveita bem as faixas de cores?
#
# ##### Não, o histograma fornecido não aproveita bem as faixas de cores pois está contido em um intervalo de até 50, quando poderia ir de 0 a 255 para uma melhor distribuição das intensidades dos pixels.
#
# 2. Equalize o histograma de maneira que a cumulativa seja uma função linear na diagonal do gráfico
# 3. Plote a imagem desenhada

# %%
img2 = cv2.equalizeHist(rintin_gray)
plt.imshow(img2, cmap="Greys_r", vmin=0, vmax=255)

# %% [markdown]
# ## Atividade 2

# %% [markdown]
# Leia com a OpenCV a figura abaixo:
#
# ![](hall_box_battery1.jpg)
#
# Separe os canais  R e B das imagens e analise seus histogramas.
#
# 1. A partir dos canais R e B e da análise do histograma é possível identificar a caixa vermelha e a bateria azul?
#
# ##### Sim. Para tanto, basta se considerar apenas os canais R ou B, respectivamente, ignorando os demais canais, e verificar os valores próximos a 255.
#
# 1. Crie uma imagem numpy em que somente os pixels da caixa vermelha estão brancos e faça seu plot aqui

# %%
caixaNaoReal = cv2.imread("hall_box_battery1.jpg");
b, g, r = cv2.split(caixaNaoReal);
img = cv2.merge((r,r,r));
plt.imshow(img);

# %%
HSV = cv2.cvtcolor(caixaNaoReal, cv2.COLOR_RGB2HSV)
h, s, v = cv2.split(HSV)

for i in range(len(h)):
    for j in range(len(h[0])):
        valor_h = h[i][j]
        valor_v = v[i][j]
        if valor_h.range(0,21) and valor_h.range(321,359):
            valor_v = 100
        else:
            valor_v = 0

plt.show(HSV)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-20756e700c9b> in <module>()
# ----> 1 HSV = cv2.cvtcolor(caixaNaoReal, cv2.COLOR_RGB2HSV)
#       2 h, s, v = cv2.split(HSV)
#       3
#       4 for i in range(len(h)):
#       5     for j in range(len(h[0])):
#
# AttributeError: 'module' object has no attribute 'cvtcolor'
